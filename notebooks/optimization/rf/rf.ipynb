# %% [markdown]
# # **Random Forest Hyperparamters Optimization**

# %% [markdown]
# ## **AUS Dataset**

# %%
from src import utilities
from src import optimization

# %%
aus_dataset_path = '../../../datasets/preprocessed/aus/'
features_scores = utilities.read_features_scores(aus_dataset_path)
train_data = utilities.read_parquet(aus_dataset_path + 'train.parquet')

optimization.optuna_search(objective=optimization.rf_objective,
                           model_name='optuna-rf-aus', data=train_data,
                           target='defaulted', k_folds=2,
                           features_scores=features_scores, features=11,
                           n_trials=100000, verbose=True)
# Out:
# Model save_path: /home/rr/DevOps/credit-scoring/models/optuna/rf/aus/2023-06-04_09-16-56/
# Selected Features: ['A8', 'A10', 'A14', 'A5', 'A7', 'A13', 'A3', 'A6', 'A2', 'A4', 'A12']
#   0%|          | 0/100000 [00:00<?, ?it/s]

# %% [markdown]
# ## **GER Dataset**

# %%
from src import utilities
from src import optimization

# %%
ger_dataset_path = '../../../datasets/preprocessed/ger/'
features_scores = utilities.read_features_scores(ger_dataset_path)
train_data = utilities.read_parquet(ger_dataset_path + 'train.parquet')

optimization.optuna_search(objective=optimization.rf_objective,
                           model_name='optuna-rf-ger', data=train_data,
                           target='defaulted', k_folds=2,
                           features_scores=features_scores, features=14,
                           n_trials=100000, verbose=True)
# Out:
# Model save_path: /home/rr/DevOps/credit-scoring/models/optuna/rf/ger/2023-06-04_13-19-08/
# Selected Features: ['exist-check-acc-status', 'credit-history', 'duration', 'sav-acc', 'purpose', 'credit-amount', 'age', 'property', 'employment-years', 'housing', 'other-install-plans', 'marriage-sex', 'install-rate', 'guarantor']
#   0%|          | 0/100000 [00:00<?, ?it/s]

# %% [markdown]
# ## **HEL Dataset**

# %%
from src import utilities
from src import optimization

# %%
hel_dataset_path = '../../../datasets/preprocessed/hel/'
features_scores = utilities.read_features_scores(hel_dataset_path)
train_data = utilities.read_parquet(hel_dataset_path + 'train.parquet')

optimization.optuna_search(objective=optimization.rf_objective,
                           model_name='optuna-rf-hel', data=train_data,
                           target='defaulted', k_folds=2,
                           features_scores=features_scores, features=9,
                           n_trials=100000, verbose=True)
# Out:
# Model save_path: /home/rr/DevOps/credit-scoring/models/optuna/rf/hel/2023-06-04_17-53-37/
# Selected Features: ['debt-to-income', 'curr-prop-val', 'oldest-credit-line', 'loan-amount', 'job', 'credit-inquiries', 'credit-lines', 'existing-amount-due', 'years-at-job']
#   0%|          | 0/100000 [00:00<?, ?it/s]

# %% [markdown]
# ## **HELOC Dataset**

# %%
from src import utilities
from src import optimization

# %%
heloc_dataset_path = '../../../datasets/preprocessed/heloc/'
features_scores = utilities.read_features_scores(heloc_dataset_path)
train_data = utilities.read_parquet(heloc_dataset_path + 'train.parquet')

optimization.optuna_search(objective=optimization.rf_objective,
                           model_name='optuna-rf-heloc', data=train_data,
                           target='defaulted', k_folds=3,
                           features_scores=features_scores, features=17,
                           n_trials=100000, verbose=True)
# Out:
# Model save_path: /home/rr/DevOps/credit-scoring/models/optuna/rf/heloc/2023-06-17_10-25-04/
# Selected Features: ['ExternalRiskEstimate', 'NetFractionRevolvingBurden', 'PercentTradesWBalance', 'MaxDelq2PublicRecLast12M', 'AverageMInFile', 'NumBank2NatlTradesWHighUtilization', 'MSinceMostRecentInqexcl7days', 'MSinceOldestTradeOpen', 'NumTrades60Ever2DerogPubRec', 'NumSatisfactoryTrades', 'PercentInstallTrades', 'NumRevolvingTradesWBalance', 'NumInqLast6M', 'NumTotalTrades', 'NetFractionInstallBurden', 'NumTradesOpeninLast12M', 'NumInstallTradesWBalance']
#   0%|          | 0/100000 [00:00<?, ?it/s]

# %% [markdown]
# ## **POL Dataset**

# %%
from src import utilities
from src import optimization

# %%
pol_dataset_path = '../../../datasets/preprocessed/pol/'
features_scores = utilities.read_features_scores(pol_dataset_path)
train_data = utilities.read_parquet(pol_dataset_path + 'train.parquet')

optimization.optuna_search(objective=optimization.rf_objective,
                           model_name='optuna-rf-pol', data=train_data,
                           target='defaulted', k_folds=3,
                           features_scores=features_scores, features=21,
                           n_trials=100000, verbose=True)
# Out:
# Model save_path: /home/rr/DevOps/credit-scoring/models/optuna/rf/pol/2023-06-17_21-22-58/
# Selected Features: ['op_act_prof/fin_exp', 'gr_prof_(in_3_years)/tot_ass', '(tot_liab*365)/(gr_prof+deprec)', '(curr_ass-inve)/st_liab', 'book_value_of_equity/tot_liab', 'op_act_prof/sales', 'work_cap', 'sales/st_liab', 'sales_(n)/sales_(n_1)', '(curr_ass-inve-receiv)/st_liab', '(curr_ass-inve-st_liab)/(sales-gr_prof-deprec)', 'sales/tot_ass', 'ret_earn/tot_ass', 'op_exp/tot_liab', 'sales/inve', 'logarithm_of_tot_ass', '(receiv*365)/sales', 'lt_liab/equity', 'rot_receiv+inve_turnover_in_days', 'sales/fix_ass', 'tot_sales/tot_ass']
#   0%|          | 0/100000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 5
#       2 features_scores = utilities.read_features_scores(pol_dataset_path)
#       3 train_data = utilities.read_parquet(pol_dataset_path + 'train.parquet')
# ----> 5 optimization.optuna_search(objective=optimization.rf_objective,
#       6                            model_name='optuna-rf-pol', data=train_data,
#       7                            target='defaulted', k_folds=3,
#       8                            features_scores=features_scores, features=21,
#       9                            n_trials=100000, verbose=True)
#
# File ~/DevOps/credit-scoring/src/optimization.py:148, in optuna_search(objective, model_name, data, target, k_folds, features_scores, features, n_trials, verbose)
#     141 skf = StratifiedKFold(n_splits=k_folds, shuffle=True)
#     143 study = optuna.create_study(directions=['maximize', 'maximize'],
#     144                             sampler=NSGAIISampler(population_size=200,
#     145                                                   mutation_prob=None,
#     146                                                   crossover_prob=0.9,
#     147                                                   swapping_prob=0.5))
# --> 148 study.optimize(lambda trial: objective(trial, data, labels, scoring, skf),
#     149                n_trials=n_trials, n_jobs=-1, catch=(ValueError, UserWarning),
#     150                show_progress_bar=True)
#     152 # save study trials csv report
#     153 study.trials_dataframe().to_csv(save_path + 'trials.csv', index=False)
#
# File ~/.local/lib/python3.10/site-packages/optuna/study/study.py:443, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     339 def optimize(
#     340     self,
#     341     func: ObjectiveFuncType,
#    (...)
#     348     show_progress_bar: bool = False,
#     349 ) -> None:
#     350     """Optimize an objective function.
#     351
#     352     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     440             If nested invocation of this method occurs.
#     441     """
# --> 443     _optimize(
#     444         study=self,
#     445         func=func,
#     446         n_trials=n_trials,
#     447         timeout=timeout,
#     448         n_jobs=n_jobs,
#     449         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     450         callbacks=callbacks,
#     451         gc_after_trial=gc_after_trial,
#     452         show_progress_bar=show_progress_bar,
#     453     )
#
# File ~/.local/lib/python3.10/site-packages/optuna/study/_optimize.py:100, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      97     break
#      99 if len(futures) >= n_jobs:
# --> 100     completed, futures = wait(futures, return_when=FIRST_COMPLETED)
#     101     # Raise if exception occurred in executing the completed futures.
#     102     for f in completed:
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:307, in wait(fs, timeout, return_when)
#     303         return DoneAndNotDoneFutures(done, not_done)
#     305     waiter = _create_and_install_waiters(fs, return_when)
# --> 307 waiter.event.wait(timeout)
#     308 for f in fs:
#     309     with f._condition:
#
# File /usr/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File /usr/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## **GMSC Dataset**

# %%
from src import utilities
from src import optimization

# %%
gmsc_dataset_path = '../../../datasets/preprocessed/gmsc/'
features_scores = utilities.read_features_scores(gmsc_dataset_path)
train_data = utilities.read_parquet(gmsc_dataset_path + 'train.parquet')

optimization.optuna_search(objective=optimization.rf_objective,
                           model_name='optuna-rf-gmsc', data=train_data,
                           target='defaulted', k_folds=3,
                           features_scores=features_scores, features=10,
                           n_trials=100000, verbose=True)

# %% [markdown]
# ## **HCDR Dataset**

# %%
from src import utilities
from src import optimization

# %%
hcdr_dataset_path = '../../../datasets/preprocessed/hcdr/'
features_scores = utilities.read_features_scores(hcdr_dataset_path)
train_data = utilities.read_parquet(hcdr_dataset_path + 'train.parquet')

optimization.optuna_search(objective=optimization.rf_objective,
                           model_name='optuna-rf-hcdr', data=train_data,
                           target='defaulted', k_folds=3,
                           features_scores=features_scores, features=28,
                           n_trials=100000, verbose=True)
